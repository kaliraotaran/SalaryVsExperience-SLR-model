# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Salary_dataset.csv')
data.head()
# Out:
#    YearsExperience  Salary
# 0              1.2   39344
# 1              1.4   46206
# 2              1.6   37732
# 3              2.1   43526
# 4              2.3   39892

# %%
data['Salary']
# Out:
# 0      39344
# 1      46206
# 2      37732
# 3      43526
# 4      39892
# 5      56643
# 6      60151
# 7      54446
# 8      64446
# 9      57190
# 10     63219
# 11     55795
# 12     56958
# 13     57082
# 14     61112
# 15     67939
# 16     66030
# 17     83089
# 18     81364
# 19     93941
# 20     91739
# 21     98274
# 22    101303
# 23    113813
# 24    109432
# 25    105583
# 26    116970
# 27    112636
# 28    122392
# 29    121873
# Name: Salary, dtype: int64

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
sns.jointplot(x = 'YearsExperience', y = 'Salary', data =data)

# %%
sns.pairplot(data = data)

# %%
sns.lmplot(x ='YearsExperience', y = 'Salary', data = data)

# %%
x = data[['YearsExperience']]

# %%
x
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
y = data['Salary']

# %%
y
# Out:
# 0      39344
# 1      46206
# 2      37732
# 3      43526
# 4      39892
# 5      56643
# 6      60151
# 7      54446
# 8      64446
# 9      57190
# 10     63219
# 11     55795
# 12     56958
# 13     57082
# 14     61112
# 15     67939
# 16     66030
# 17     83089
# 18     81364
# 19     93941
# 20     91739
# 21     98274
# 22    101303
# 23    113813
# 24    109432
# 25    105583
# 26    116970
# 27    112636
# 28    122392
# 29    121873
# Name: Salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train , y_test = train_test_split(x, y, test_size=0.2, random_state=True)

# %%
x_train
# Out:
#     YearsExperience
# 26              9.6
# 3               2.1
# 24              8.8
# 22              8.0
# 23              8.3
# 4               2.3
# 2               1.6
# 25              9.1
# 6               3.1
# 18              6.0
# 13              4.2
# 7               3.3
# 27              9.7
# 1               1.4
# 16              5.2
# 0               1.2
# 15              5.0
# 29             10.6
# 28             10.4
# 9               3.8
# 8               3.3
# 12              4.1
# 11              4.1
# 5               3.0

# %%
x_test
# Out:
#     YearsExperience
# 17              5.4
# 21              7.2
# 10              4.0
# 19              6.1
# 14              4.6
# 20              6.9

# %%
y_train
# Out:
# 26    116970
# 3      43526
# 24    109432
# 22    101303
# 23    113813
# 4      39892
# 2      37732
# 25    105583
# 6      60151
# 18     81364
# 13     57082
# 7      54446
# 27    112636
# 1      46206
# 16     66030
# 0      39344
# 15     67939
# 29    121873
# 28    122392
# 9      57190
# 8      64446
# 12     56958
# 11     55795
# 5      56643
# Name: Salary, dtype: int64

# %%
y_test
# Out:
# 17    83089
# 21    98274
# 10    63219
# 19    93941
# 14    61112
# 20    91739
# Name: Salary, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept=True)

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Coefficent (m)', regressor.coef_)
print('Linear Coefficient (b)', regressor.intercept_)
# Out:
# Linear Coefficent (m) [9332.94473799]
# Linear Coefficient (b) 24677.603524555554

# %%
x_test
# Out:
#     YearsExperience
# 17              5.4
# 21              7.2
# 10              4.0
# 19              6.1
# 14              4.6
# 20              6.9

# %%
ypredict = regressor.predict(x_test)
ypredict
# Out:
# array([75075.50510972, 91874.8056381 , 62009.38247653, 81608.56642631,
#        67609.14931932, 89074.92221671])

# %%
y_test
# Out:
# 17    83089
# 21    98274
# 10    63219
# 19    93941
# 14    61112
# 20    91739
# Name: Salary, dtype: int64

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, regressor.predict(x_train), color = 'red')
plt.xlabel('Years Of Experience')
plt.ylabel('Salary')
plt.title('The Increase in Salary of Employee as They gain more Experience')
# Out:
# Text(0.5, 1.0, 'The Increase in Salary of Employee as They gain more Experience')

# %%
Experience = [[20]]
salary = regressor.predict(Experience)
salary
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([211336.49828441])
